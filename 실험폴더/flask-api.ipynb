# %%
db_crawler('user_id')
# Out:
# ["사용자 이름: name, 사용자 직책: -, 사용자 부서: 개발팀오늘은 2024-09-05, Thursday입니다.2024-09-03 03:16:59에 name이(가) '오늘까지 스쿼트 100번하세요'라 말함. 2024-09-03 03:17:32에 name이(가) '내일은 팔굽혀펴기 200번 하세요'라 말함. 2024-09-03 03:17:59에 name이(가) '4시까지 윗몸일으키기 300번하세요'라 말함. 2024-09-03 03:18:16에 name이(가) '점심으로 짜장면 먹습니다'라 말함. 2024-09-03 03:18:25에 name이(가) '탕비실에 참크래커 넣어주세요'라 말함. 2024-09-03 03:18:41에 name이(가) ''오라클로 배우는 데이터베이스 입문' 서고에 반납했습니다'라 말함. 2024-09-03 03:19:15에 name이(가) '자바스크립트 공부는 얼마나 하셨나요'라 말함. 2024-09-03 03:19:29에 name이(가) '스마티어 서포터즈 프로젝트 진행해주세요'라 말함. 2024-09-03 10:17:28에 name이(가) 'zfa'라 말함. 2024-09-04 00:29:08에 메식이이(가) '호날두 보러 가게같이 풋살이나 차자'라 말함. 2024-09-04 00:30:12에 제로이(가) '레고'라 말함. 2024-09-04 00:30:25에 제로이(가) 'ㄲㄱ'라 말함. 2024-09-04 00:30:34에 제로이(가) 'ㅁㄴㅇ'라 말함. 2024-09-04 00:30:41에 제로이(가) 'ㅁㄴㅇ'라 말함. 2024-09-04 00:30:47에 제로이(가) 'ㄲㄲㄲㄲㄲㄲㄲㄲㄲㄲ'라 말함. 2024-09-04 00:32:06에 메식이이(가) '잘나옴?오늘 찍어봄'라 말함. 2024-09-04 00:36:09에 name이(가) '메식아 셀카다시 보내봐 '라 말함. 2024-09-04 00:36:57에 메식이이(가) '오늘 셀카찍음 잘나옴?'라 말함. 2024-09-04 00:37:06에 name이(가) '긋긋'라",
#  "말함. 2024-09-04 00:32:06에 메식이이(가) '잘나옴?오늘 찍어봄'라 말함. 2024-09-04 00:36:09에 name이(가) '메식아 셀카다시 보내봐 '라 말함. 2024-09-04 00:36:57에 메식이이(가) '오늘 셀카찍음 잘나옴?'라 말함. 2024-09-04 00:37:06에 name이(가) '긋긋'라 말함. 2024-09-04 00:40:15에 메식이이(가) '아아아아'라 말함. 2024-09-04 00:40:24에 메식이이(가) '축구접을까'라 말함. 2024-09-04 00:46:11에 메식이이(가) '축구... 어렵다..'라 말함. 2024-09-04 05:33:11에 name이(가) 'ㅎㅇㅎㅇ'라 말함. 2024-09-04 06:41:20에 메식이이(가) '날도야 두바이 살만하냐'라 말함. 2024-09-04 06:42:26에 name이(가) '하위'라 말함. 2024-09-04 07:43:54에 name이(가) '프로젝트 테스트 01'라 말함. 2024-09-05 01:44:20에 name이(가) '1'라 말함. 2024-09-05 01:44:20에 name이(가) '2'라 말함. 2024-09-05 01:44:20에 name이(가) '3'라 말함. 2024-09-05 01:44:20에 name이(가) '4'라 말함. 2024-09-05 01:44:20에 name이(가) '4'라 말함. 2024-09-05 01:44:22에 name이(가) '와'라 말함. 2024-09-05 01:44:22에 name이(가) '아'라 말함. 2024-09-05 01:44:23에 name이(가) '이제'라 말함. 2024-09-05 01:44:27에 name이(가) '이란'라 말함. 2024-09-05 01:48:25에 name이(가) '1'라 말함. 2024-09-05 01:48:25에 name이(가) '1'라 말함. 2024-09-05 01:48:26에 name이(가) '2'라 말함. 2024-09-05 01:48:28에",
#  "name이(가) '이제'라 말함. 2024-09-05 01:44:27에 name이(가) '이란'라 말함. 2024-09-05 01:48:25에 name이(가) '1'라 말함. 2024-09-05 01:48:25에 name이(가) '1'라 말함. 2024-09-05 01:48:26에 name이(가) '2'라 말함. 2024-09-05 01:48:28에 name이(가) '1243'라 말함. 2024-09-05 03:20:21에 name이(가) 'ㅎㅇㅇ'라 말함. 2024-09-05 03:20:38에 name이(가) 'ㅎㅇㅎㅇㅎㅇ'라 말함. 2024-09-05 03:21:17에 name이(가) 'ㅎㅇㅎ'라 말함. 2024-09-05 03:21:19에 name이(가) 'ㅁㄴ'라 말함. 2024-09-03 00:00:00부터 2024-09-06 00:00:00까지 일정: 'HTML 개발'이 있습니다. 2024-09-03 00:00:00부터 2024-09-09 00:00:00까지 일정: '개발 집중 기간'이 있습니다. 2024-09-09 00:00:00부터 2024-09-12 00:00:00까지 일정: '발표 ppt 준비'이 있습니다. 2024-09-11 12:00:00부터 2024-09-11 13:00:00까지 일정: '잠자기'이 집에서 있습니다. 2024-09-12 16:00:00부터 2024-09-12 18:00:00까지 일정: '최종 발표 리허설!!'이 있습니다. 2024-09-13 13:00:00부터 2024-09-13 13:00:00까지 일정: '수료'이 있습니다. 2024-09-13 13:30:00부터 2024-09-13 13:32:59까지 일정: '최종발표 우승'이 601에서 있습니다. 2024-09-18 12:00:00부터 2024-09-18 13:00:00까지 일정: '제발 버그나지 말아주세요'이 세스코에서 있습니다. 2024-09-19 00:00:00부터 2024-09-19 00:00:00까지 일정: 'test'이 test에서 있습니다.",
#  "2024-09-13 13:32:59까지 일정: '최종발표 우승'이 601에서 있습니다. 2024-09-18 12:00:00부터 2024-09-18 13:00:00까지 일정: '제발 버그나지 말아주세요'이 세스코에서 있습니다. 2024-09-19 00:00:00부터 2024-09-19 00:00:00까지 일정: 'test'이 test에서 있습니다. 2024-09-30 00:00:00부터 2024-10-05 00:00:00까지 일정: '휴가'이 파리에서 있습니다. 호날도은(는) FC모아이 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.mma은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.카타리나은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.갈리오은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.메식이은(는) FC모아이 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.투구은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.name은(는) 개발팀 부서의 - 직책을 담당하고 있습니다. 연락처는 010-0000-0000 입니다.그라가스은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.제로은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.뽀삐은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.나미은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.나서스은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.너은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다.",
#  '미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.나미은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.나서스은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.너은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 undefined-undefined-undefined 입니다.32323은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 010-3648-1285 입니다.달력최고은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.정성문은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.대표은(는) 부서 미지정 부서의 +821036481285 직책을 담당하고 있습니다. 연락처는 11 입니다.김대표은(는) 부서 미지정 부서의 +821036481285 직책을 담당하고 있습니다. 연락처는 11 입니다.임대표은(는) 부서 미지정 부서의 +821036481285 직책을 담당하고 있습니다. 연락처는 11 입니다.테스트성문은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 11 입니다.zz은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 11 입니다.홍길동은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.세라핀은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.에슾하은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.가렌은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.name00은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 010-0000-0000',
#  '연락처는 +821036481285 입니다.에슾하은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.가렌은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.name00은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 010-0000-0000 입니다.name01은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 010-0000-0000 입니다.name03은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 010-0000-0000 입니다.name04은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 010-0000-0000 입니다.name05은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 010-0000-0000 입니다.87541754175은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 010-3648-1285 입니다.hellosmhrd은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 010-3648-1285 입니다.444은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 undefined-undefined-undefined 입니다.zimball은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.fafa은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.name02은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 010-0000-0000 입니다.fifi은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.드레이븐은(는) 부서 미지정 부서의 대리 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.푸바오은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다.',
#  '- 직책을 담당하고 있습니다. 연락처는 010-0000-0000 입니다.fifi은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.드레이븐은(는) 부서 미지정 부서의 대리 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.푸바오은(는) 부서 미지정 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.아무무은(는) 개발팀 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.갱플랭크은(는) 개발팀 부서의 - 직책을 담당하고 있습니다. 연락처는 +821036481285 입니다.메식이님에게 결재 신청한 [DI]_ChatGPT의_파급_효과와_기관의_LLM_도입_전략.pdf 문서는 미승인 상태 입니다.그라가스님에게 결재 신청한 academic_writing11.pdf 문서는 2024-09-04 06:09:33에 승인되었습니다.name00님에게 결재 신청한 기획발표.pdf 문서는 2024-09-03 10:24:24에 승인되었습니다.드레이븐님에게 결재 신청한 Web API Service 만들기 - 한국수출입은행 오픈 API.pdf 문서는 2024-09-04 02:26:08에 승인되었습니다.드레이븐님에게 결재 신청한 기획발표.pdf 문서는 미승인 상태 입니다.드레이븐님에게 결재 신청한 PCCE 성적표 김광오_프로그래머스인증시험.pdf 문서는 미승인 상태 입니다.']

# %%
from pypdf import PdfReader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.chat_models import ChatOllama
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain_community.vectorstores import FAISS
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_core.prompts.prompt import PromptTemplate
from langchain.chains import ConversationalRetrievalChain
from langchain.memory import ConversationBufferMemory
from docx import Document
from flask import *
from flask_cors import CORS
import json
import os
import sys
import datetime
from langchain_postgres import PGVector
from langchain_postgres.vectorstores import PGVector
import psycopg2
from psycopg2 import pool

dbcp = psycopg2.pool.SimpleConnectionPool(1, 20,
    user='postgres.vpcdvbdktvvzrvjfyyzm',
    password='Odvv8E1iChKjwai4',
    host='aws-0-ap-southeast-1.pooler.supabase.com',
    port=6543,
    dbname='postgres'
)

app = Flask(__name__)
# CORS(app, resources={r'*': {'origins': 'http://localhost:8000'}})
CORS(app)
host = 'localhost'
port = 5100

connection='postgresql+psycopg2://postgres.vpcdvbdktvvzrvjfyyzm:Odvv8E1iChKjwai4@aws-0-ap-southeast-1.pooler.supabase.com:6543/postgres'

# Configuration
ngrok = ''
ngrok = 'https://d3c4-34-141-163-31.ngrok-free.app'
device = 'cpu'

if ngrok == '':
    llm_model = ChatOllama(
        model='meta-llama-3.1',
    )
    llm_model_json = ChatOllama(
        model='meta-llama-3.1',
        format='json', 
    )
else:
    # Load language model
    llm_model = ChatOllama(
        model='meta-llama-3.1',
        base_url=ngrok      # 주석 해제 시 코랩 자원으로 돌아감, # 주석 설정 시 로컬 자원으로 돌아감 
    )
    llm_model_json = ChatOllama(
        model='meta-llama-3.1',
        format='json', 
        base_url=ngrok       # 주석 해제 시 코랩 자원으로 돌아감, # 주석 설정 시 로컬 자원으로 돌아감 
    )

# Load embeddings model
embedding_model = HuggingFaceEmbeddings(
    model_name="BAAI/bge-m3",
    model_kwargs={'device': device},
    encode_kwargs={'normalize_embeddings': True}
)

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)

# Define prompt
prompt_template = '''Use the following pieces of context to answer the question at the end.
If you don't find the answer in context, don't try to make up an answer.
If you find the answer in context, answer me only use korean.

context: {chat_history}

Question: {question}
Helpful Answer:'''
# rag_prompt = PromptTemplate.from_template(prompt_template)
rag_prompt = PromptTemplate(template=prompt_template, input_variables=['chat_history', 'question'])

prompt_template = '''Use the following pieces of context to answer the question at the end.
If you don't find the answer in context, don't try to make up an answer.
If you find the answer in context, answer me only use korean.

context: {chat_history}

Question: {question}
Helpful Answer:'''
# rag_prompt = PromptTemplate.from_template(prompt_template)
chat_prompt = PromptTemplate(template=prompt_template, input_variables=['chat_history', 'question'])



#db에서 접근 권한이 있는 정보를 문장으로 만들어 분할하는 함수
def db_crawler(user_id):
    db = dbcp.getconn()
    cur = db.cursor()
    cur.execute("""
                select user_name, job_id, dep_name 
                from users u join departments d on u.dep_id = d.dep_id
                where user_id=%s
                """,
                (user_id,))
    user_info = cur.fetchone()
    cur.execute("""
                select cl.chat_at, u.user_name, cl.cl_chat
                from chat_logs cl join users u on cl.user_id = u.user_id
                where cl_type = 'text' and room_id in (select room_id from room_users where user_id = %s)
                order by chat_at
                """,
                (user_id,))
    chat_rows = cur.fetchall()
    cur.execute("""
                select cal_title, cal_start_date, cal_end_date, cal_location
                from calendars
                where user_id = %s or cal_id in (select cal_sub_id from calendar_shared)
                order by cal_start_date
                """,
                (user_id,))
    cal_rows = cur.fetchall()
    cur.execute("""
                select user_name, job_id, dep_name, user_phone
                from users u join departments d on u.dep_id = d.dep_id
                """)
    member_rows = cur.fetchall()
    cur.execute("""
                select c_title, c_category, c_date_range, c_assignee
                from cards
                where dep_id = (
                    select dep_id
                    from users
                    where user_id = %s
                )
                """,
                (user_id,))
    cur.execute("""
                select p_title, user_name, app_at
                from payment p join users u on p.p_app = u.user_id
                where p_uploader = %s
                """,
                (user_id,))
    payreq_rows = cur.fetchall()
    cur.execute("""
                select p_title, user_name, app_at
                from payment p join users u on p.p_uploader = u.user_id
                where p_app =  %s 
                """,
                (user_id,))
    payres_rows = cur.fetchall()
    task_rows = cur.fetchall()
    
    dbcp.putconn(db)

    db_crawls = f'사용자 이름: {user_info[0]}, 사용자 직책: {user_info[1]}, 사용자 부서: {user_info[2]}'
    db_crawls += datetime.datetime.now().strftime('오늘은 %G-%m-%d, %A입니다.')

    for row in chat_rows:
        _ = '\n'
        db_crawls += f"{row[0].strftime('%G-%m-%d %T')}에 {row[1]}이(가) '{row[2].replace(_, '')}'라 말함. "
    for row in cal_rows:
        db_crawls += f"{row[1].replace('T', ' ')}부터 {row[2].replace('T', ' ')}까지 일정: '{row[0]}'이 {row[3] +'에서 ' if row[3] else ''}있습니다. "
    for row in member_rows:
        db_crawls += f"{row[0]}은(는) {row[2]} 부서의 {row[1]} 직책을 담당하고 있습니다. 연락처는 {row[3]} 입니다."
    for row in task_rows:
        db_crawls += f"'{row[0]}' 업무는 {row[1]} 상태이며 {'일정은 '+row[2] +'입니다.' if row[2] else ''} {'담당자는 ' +row[3] +'입니다.' if row[3] else ''}"
    for row in payreq_rows:
        # print(row[2] if )
        db_crawls += f"{row[1]}님에게 결재 신청한 {row[0]} 문서는 {row[2].strftime('%G-%m-%d %T')+ '에 승인되었습니다.' if row[2] else '미승인 상태 입니다.'}"
    for row in payres_rows:
        db_crawls += f"{row[1]}님이 결재 신청한 {row[0]} 문서는 {row[2].strftime('%G-%m-%d %T')+ '에 승인하셨습니다.' if row[2] else '미승인 상태 입니다.'}"

    
    db_split = text_splitter.split_text(db_crawls)
    
    return db_split

def process_file(file_path, user_input, user_id):
    text_sum = ''
    db_split = db_crawler(user_id)

    for file in file_path:
        try:
            reader = PdfReader(file)
            for page in reader.pages:  # 페이지 별로 텍스트 추출
                text = page.extract_text()
                corrected_text = text.encode('utf-8', errors='ignore').decode('utf-8')  # 인코딩 오류 무시 및 텍스트 누적
                text_sum += corrected_text + '\n'
        except Exception as e:
            print(e)
            continue
    splits = text_splitter.split_text(text_sum)
    splits += db_split
    # if len(splits) == 0: 
    #         return False
        
    # Create FAISS index
    vectorstore = FAISS.from_texts(splits, embedding_model)
    
    question = f'사용자의 입력: {user_input}'+'''
    사용자의 입력을 보고 주제를 정해서 문서 요약 관련 보고서를 만들어줘
    {
        'title': '보고서의 제목',
        'content':list['보고서의 목차별 제목'] 20글자 이내,
        'summary': '보고서의 개요' 1000글자 이내
    }
    key is title, content, summary.
    Respond using JSON only.'''
    memory = ConversationBufferMemory(
        memory_key='chat_history',
        return_messages=True,
    )

    conversation_chain = ConversationalRetrievalChain.from_llm(
        llm=llm_model_json,
        retriever=vectorstore.as_retriever(),
        condense_question_prompt=rag_prompt,
        memory=memory,
    )
    res = conversation_chain({'question': question})
    response = res['chat_history'][1].content.replace('\n', '').lstrip().rstrip()
    response = json.loads(response)

    return create_docx(response, vectorstore)

# Function to create the DOCX file
def create_docx(response, vectorstore):
    doc = Document()
    title = response.get('title', '제목 없음')
    doc.add_heading(title, level=0)

    doc.add_heading('목차', level=1)
    doc.add_paragraph('1. 개요')
    doc.add_paragraph('2. 본문')
    for n, cont in enumerate(response.get('content', []), 1):
        doc.add_paragraph(f'\t2-{n}. {cont}')

    doc.add_heading('1. 개요', level=1)
    doc.add_paragraph(response.get('summary', ''))

    doc.add_heading('2. 본문', level=1)
    for n, cont in enumerate(response.get('content', []), 1):
        question = f'제목이 "{title}"인 보고서의 "{cont}" 부분 상세 내용을 글로 풀어서 적어줘'    # {title}라는 보고서의 {cont} 부분 상세 내용 markdown 형식으로
        memory = ConversationBufferMemory(
            memory_key='chat_history',
            return_messages=True
        )
        conversation_chain = ConversationalRetrievalChain.from_llm(
            llm=llm_model,
            retriever=vectorstore.as_retriever(),
            condense_question_prompt=rag_prompt,
            memory=memory
        )
        res = conversation_chain({'question': question})
        doc.add_heading(f'\t2-{n}. {cont}', level=2)
        doc.add_paragraph(res['chat_history'][1].content)
    
    # Format date to avoid issues in filenames
    doc.save(f'./processed/{datetime.datetime.today().strftime("%g%m%d%H%M%S")}.docx')
    return f'/processed/{datetime.datetime.today().strftime("%g%m%d%H%M%S")}.docx'

@app.route('/summary', methods=['POST'])
def summary():
    user_input = request.form.get('inputText', '').strip()
    user_id = request.form.get('user_id')
    files = [request.files[i] for i in request.files]
    processedFilePath = process_file(files, user_input, user_id)
    
    if processedFilePath:
        return jsonify({
            'result': 'ok',
            'processedFilePath': processedFilePath
        })
    else:
        return jsonify({
            'result': 'error',
            'error': '텍스트를 인식할 수 없음'
        })

@app.route('/chat', methods=['POST'])
def chat():
    params = request.get_json()
    user_input = params.get('user_input')
    user_id = params.get('user_id')
    # print(params)
    splits = db_crawler(user_id)
    vectorstore = FAISS.from_texts(splits, embedding_model)

    memory = ConversationBufferMemory(
        memory_key='chat_history',
        return_messages=True
    )
    conversation_chain = ConversationalRetrievalChain.from_llm(
        llm=llm_model,
        retriever=vectorstore.as_retriever(),
        condense_question_prompt=chat_prompt,
        memory=memory
    )
    
    conn = dbcp.getconn()
    cur = conn.cursor()
    
    cur.execute(
        "select ac_question, ac_answer from ai_chat_logs where user_id=%s order by chat_at asc",
        (user_id,)
    )
    rows = cur.fetchall()
    
    cur.close()
    dbcp.putconn(conn)
    
    for row in rows:
        memory.save_context(
            inputs={'human': row[0]},
            outputs={'ai': row[1]}
        )
        
    res = conversation_chain({'question': user_input})
    
    conn = dbcp.getconn()
    cur = conn.cursor()
    
    cur.execute(
        "insert into ai_chat_logs (user_id, ac_question, ac_answer) values (%s, %s, %s)",
        (user_id, user_input, res['answer'])
    )
    conn.commit()
    
    cur.close()
    dbcp.putconn(conn)
    return jsonify({'answer': res['answer']})
       
if __name__ == '__main__':
    app.run(host= host, port=port)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://localhost:5100
# Press CTRL+C to quit
# 127.0.0.1 - - [05/Sep/2024 16:42:32] "OPTIONS /chat HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Sep/2024 16:43:23] "POST /chat HTTP/1.1" 200 -
